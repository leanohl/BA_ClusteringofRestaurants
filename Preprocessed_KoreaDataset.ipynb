# %% [markdown]
# Team5 project / Preprocessing

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
#import data
df= pd.read_csv('data/KoreaIncomeData.csv') 
df.head() # 40441 rows and 199 columns
#'Gu' is represent as 3-digits number codes
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15288/3965934167.py in <module>
#       1 #import data
# ----> 2 df= pd.read_csv('data/KoreaIncomeData.csv')
#       3 df.head() # 40441 rows and 199 columns
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#We only use 'Gu' and 'Income' data.
df=df.copy()[['GU','ADQ3E']]

#Change the column names
df.columns = ['Gu','Income']

#Drop null data and we have 27443 rows and 2 columns
nullIndex=df[(df['Income']=='#NULL!')].index
df.drop(nullIndex,inplace=True)
df
# Out:
#         Gu Income
# 0      110      9
# 1      110      6
# 2      110     16
# 3      110     12
# 5      110      7
# ...    ...    ...
# 40435  500     21
# 40436  680      6
# 40437  545      6
# 40438  590      5
# 40440  620     16
#
# [27443 rows x 2 columns]

# %%
#change type to float
df=df.astype('float')

# %%
#using grouby method and get mean of income and sum up with total 25 'Gu'
df=df.groupby('Gu').mean().reset_index()
df
# Out:
#        Gu    Income
# 0   110.0  8.092664
# 1   140.0  7.359223
# 2   170.0  8.214203
# 3   200.0  8.231841
# 4   215.0  7.091238
# 5   230.0  7.376686
# 6   260.0  6.981943
# 7   290.0  7.101276
# 8   305.0  7.071233
# 9   320.0  6.829268
# 10  350.0  7.007524
# 11  380.0  6.911238
# 12  410.0  7.296404
# 13  440.0  7.635865
# 14  470.0  7.808050
# 15  500.0  7.054054
# 16  530.0  7.261722
# 17  545.0  6.289532
# 18  560.0  7.784946
# 19  590.0  7.495265
# 20  620.0  6.372960
# 21  650.0  8.688123
# 22  680.0  9.710548
# 23  710.0  8.212038
# 24  740.0  7.254443

# %%
#About Gu information
#change 3-digit code to real name
df['Gu']=df.Gu.replace({110:"Jongno-gu",140:"Jung-gu",170:"Yongsan-gu",200:"Seongdong-gu",215:"Gwangjin-gu",230:"Dongdaemun-gu",260:"Jungnang-gu",290:"Seongbuk-gu",305:"Gangbuk-gu",320:"Dobong-gu",350:"Nowon-gu",380:"Eunpyeong-gu",410:"Seodaemun-gu",440:"Mapo-gu",470:"Yangcheon-gu",500:"Gangseo-gu",530:"Guro-gu",545:"Geumcheon-gu",560:"Yeongdeungpo-gu",590:"Dongjak-gu",620:"Gwanak-gu",650:"Seocho-gu",680:"Gangnam-gu",710:"Songpa-gu",740:"Gangdong-gu"})
Korea_income=df.copy()
Korea_income.head()
# Out:
#              Gu    Income
# 0     Jongno-gu  8.092664
# 1       Jung-gu  7.359223
# 2    Yongsan-gu  8.214203
# 3  Seongdong-gu  8.231841
# 4   Gwangjin-gu  7.091238

# %%
#About Income information
#df['Income']=df.Income.replace({'1':"Under 100",'2':"Under 100",'3':"100~200",'4':"100~200",'5':"200~300",'6':"200~300",'7':"300~400",'8':"300~400",'9':"400~500",'10':"400~500",'11':"500~600",'12':"500~600",'13':"600~700",'14':"600~700",'15':"700~800",'16':"700~800",'17':"800~900",'18':"800~900",'19':"900~1000",'20':'900~1000','21':"Over 1000"})

# %%
#Korea_income.Income.value_counts()

# %%
# Preprocessing foreign dataset
df2= pd.read_csv('data/KoreaForeignRawData.csv')
df2.head()
# Out:
#    자치구별(1)  자치구별(2)  2021   2021 .1         2021 .2 2021 .3 2021 .4 2021 .5  \
# 0  자치구별(1)  자치구별(2)     합계       합계              합계      합계      합계      합계
# 1  자치구별(1)  자치구별(2)     소계  한국계 중국인  중국(한국계 중국인 제외)      미국     타이완      일본
# 2  자치구별(1)  자치구별(2)      계        계               계       계       계       계
# 3       합계      종로구  9106      992            2637     630     220     318
# 4      NaN       중구  9288     1294            2227     280     534     285
#
#   2021 .6 2021 .7  ... 2021 .50   2021 .51 2021 .52   2021 .53 2021 .54  \
# 0      합계      합계  ...       합계         합계       합계         합계       합계
# 1     베트남      몽골  ...    오스트리아  수       단    아르헨티나  오       만  이 스 라 엘
# 2       계       계  ...        계          계        계          계        계
# 3   2111      71   ...      23          1         -         5       41
# 4   1424     265   ...      11           -       1          1        8
#
#     2021 .55 2021 .56 2021 .57 2021 .58   2021 .59
# ...

# %%
#drop unneeded index
df2= df2.drop(df2.index[[0,1,2]])
df2.head()
# Out:
#   자치구별(1) 자치구별(2)   2021  2021 .1 2021 .2 2021 .3 2021 .4 2021 .5 2021 .6  \
# 3      합계     종로구   9106     992    2637     630     220     318    2111
# 4     NaN      중구   9288    1294    2227     280     534     285    1424
# 5     NaN     용산구  14332     776     538    2554     314    1116     271
# 6     NaN     성동구   6682    1472    2151     225     137     243     945
# 7     NaN     광진구  12631    4049    3504     175     127     378    1585
#
#   2021 .7  ... 2021 .50 2021 .51 2021 .52 2021 .53 2021 .54 2021 .55 2021 .56  \
# 3     71   ...      23        1         -       5       41        5        4
# 4    265   ...      11         -       1        1        8       29       23
# 5    159   ...       9       81       24         -      24       52       48
# 6    205   ...       1        1         -        -       1        2        6
# 7    856   ...       5        1        4        1         -       1        5
#
#   2021 .57 2021 .58 2021 .59
# 3       7         -     239
# ...

# %%
df2= df2.drop(df2.columns[[0,1]],axis=1)
df2.head()
# Out:
#     2021  2021 .1 2021 .2 2021 .3 2021 .4 2021 .5 2021 .6 2021 .7 2021 .8  \
# 3   9106     992    2637     630     220     318    2111      71      56
# 4   9288    1294    2227     280     534     285    1424     265      95
# 5  14332     776     538    2554     314    1116     271     159     585
# 6   6682    1472    2151     225     137     243     945     205     158
# 7  12631    4049    3504     175     127     378    1585     856      89
#
#   2021 .9  ... 2021 .50 2021 .51 2021 .52 2021 .53 2021 .54 2021 .55 2021 .56  \
# 3     34   ...      23        1         -       5       41        5        4
# 4     96   ...      11         -       1        1        8       29       23
# 5    214   ...       9       81       24         -      24       52       48
# 6     38   ...       1        1         -        -       1        2        6
# 7     45   ...       5        1        4        1         -       1        5
#
#   2021 .57 2021 .58 2021 .59
# 3       7         -     239
# ...

# %%
#df2.insert(1,'Gu',['Jongno-gu',"Jung-gu","Yongsan-gu","Seongdong-gu","Gwangjin-gu","Dongdaemun-gu","Jungnang-gu","Seongbuk-gu","Gangbuk-gu","Dobong-gu","Nowon-gu","Eunpyeong-gu","Seodaemun-gu","Mapo-gu","Yangcheon-gu","Gangseo-gu","Guro-gu","Geumcheon-gu","Yeongdeungpo-gu","Dongjak-gu","Gwanak-gu","Seocho-gu","Gangnam-gu","Songpa-gu","Gangdong-gu"],True)
#df2.head()

# %%
#df2=df2.drop(df2.columns[[0]],axis=1)
#df2.head()

# %%
#replace '-' to 0. To avoid error occur
df2=df2.replace('-',0)
df2.head()
# Out:
#     2021  2021 .1 2021 .2 2021 .3 2021 .4 2021 .5 2021 .6 2021 .7 2021 .8  \
# 3   9106     992    2637     630     220     318    2111      71      56
# 4   9288    1294    2227     280     534     285    1424     265      95
# 5  14332     776     538    2554     314    1116     271     159     585
# 6   6682    1472    2151     225     137     243     945     205     158
# 7  12631    4049    3504     175     127     378    1585     856      89
#
#   2021 .9  ... 2021 .50 2021 .51 2021 .52 2021 .53 2021 .54 2021 .55 2021 .56  \
# 3     34   ...      23        1         0       5       41        5        4
# 4     96   ...      11         0       1        1        8       29       23
# 5    214   ...       9       81       24         0      24       52       48
# 6     38   ...       1        1         0        0       1        2        6
# 7     45   ...       5        1        4        1         0       1        5
#
#   2021 .57 2021 .58 2021 .59
# 3       7         0     239
# ...

# %%
#rearrange index
df2.reset_index(drop=True,inplace=True)
df2.head()
# Out:
#     2021  2021 .1 2021 .2 2021 .3 2021 .4 2021 .5 2021 .6 2021 .7 2021 .8  \
# 0   9106     992    2637     630     220     318    2111      71      56
# 1   9288    1294    2227     280     534     285    1424     265      95
# 2  14332     776     538    2554     314    1116     271     159     585
# 3   6682    1472    2151     225     137     243     945     205     158
# 4  12631    4049    3504     175     127     378    1585     856      89
#
#   2021 .9  ... 2021 .50 2021 .51 2021 .52 2021 .53 2021 .54 2021 .55 2021 .56  \
# 0     34   ...      23        1         0       5       41        5        4
# 1     96   ...      11         0       1        1        8       29       23
# 2    214   ...       9       81       24         0      24       52       48
# 3     38   ...       1        1         0        0       1        2        6
# 4     45   ...       5        1        4        1         0       1        5
#
#   2021 .57 2021 .58 2021 .59
# 0       7         0     239
# ...

# %%
#df2.['Gu']=['Jongno-gu',"Jung-gu","Yongsan-gu","Seongdong-gu","Gwangjin-gu","Dongdaemun-gu","Jungnang-gu","Seongbuk-gu","Gangbuk-gu","Dobong-gu","Nowon-gu","Eunpyeong-gu","Seodaemun-gu","Mapo-gu","Yangcheon-gu","Gangseo-gu","Guro-gu","Geumcheon-gu","Yeongdeungpo-gu","Dongjak-gu","Gwanak-gu","Seocho-gu","Gangnam-gu","Songpa-gu","Gangdong-gu"]
#df2.index=['Jongno-gu',"Jung-gu","Yongsan-gu","Seongdong-gu","Gwangjin-gu","Dongdaemun-gu","Jungnang-gu","Seongbuk-gu","Gangbuk-gu","Dobong-gu","Nowon-gu","Eunpyeong-gu","Seodaemun-gu","Mapo-gu","Yangcheon-gu","Gangseo-gu","Guro-gu","Geumcheon-gu","Yeongdeungpo-gu","Dongjak-gu","Gwanak-gu","Seocho-gu","Gangnam-gu","Songpa-gu","Gangdong-gu"]
#df2

# %%
#change type to float
df2=df2.astype('float')
df2.head()
# Out:
#      2021   2021 .1  2021 .2  2021 .3  2021 .4  2021 .5  2021 .6  2021 .7  \
# 0   9106.0    992.0   2637.0    630.0    220.0    318.0   2111.0     71.0
# 1   9288.0   1294.0   2227.0    280.0    534.0    285.0   1424.0    265.0
# 2  14332.0    776.0    538.0   2554.0    314.0   1116.0    271.0    159.0
# 3   6682.0   1472.0   2151.0    225.0    137.0    243.0    945.0    205.0
# 4  12631.0   4049.0   3504.0    175.0    127.0    378.0   1585.0    856.0
#
#    2021 .8  2021 .9  ...  2021 .50  2021 .51  2021 .52  2021 .53  2021 .54  \
# 0     56.0     34.0  ...      23.0       1.0       0.0       5.0      41.0
# 1     95.0     96.0  ...      11.0       0.0       1.0       1.0       8.0
# 2    585.0    214.0  ...       9.0      81.0      24.0       0.0      24.0
# 3    158.0     38.0  ...       1.0       1.0       0.0       0.0       1.0
# 4     89.0     45.0  ...       5.0       1.0       4.0       1.0       0.0
#
#    2021 .55  2021 .56  2021 .57  2021 .58  2021 .59
# ...

# %%
#make new colums
df2['Total'] = df2.iloc[:,0]
df2['Chinese'] = df2.iloc[:,2]
df2['Japanese'] = df2.iloc[:,5]
df2.head()
# Out:
#      2021   2021 .1  2021 .2  2021 .3  2021 .4  2021 .5  2021 .6  2021 .7  \
# 0   9106.0    992.0   2637.0    630.0    220.0    318.0   2111.0     71.0
# 1   9288.0   1294.0   2227.0    280.0    534.0    285.0   1424.0    265.0
# 2  14332.0    776.0    538.0   2554.0    314.0   1116.0    271.0    159.0
# 3   6682.0   1472.0   2151.0    225.0    137.0    243.0    945.0    205.0
# 4  12631.0   4049.0   3504.0    175.0    127.0    378.0   1585.0    856.0
#
#    2021 .8  2021 .9  ...  2021 .53  2021 .54  2021 .55  2021 .56  2021 .57  \
# 0     56.0     34.0  ...       5.0      41.0       5.0       4.0       7.0
# 1     95.0     96.0  ...       1.0       8.0      29.0      23.0      11.0
# 2    585.0    214.0  ...       0.0      24.0      52.0      48.0     103.0
# 3    158.0     38.0  ...       0.0       1.0       2.0       6.0       8.0
# 4     89.0     45.0  ...       1.0       0.0       1.0       5.0       7.0
#
#    2021 .58  2021 .59    Total  Chinese  Japanese
# ...

# %%
#because our type of cuisine is divided by 4(asian, western, chinese, japanese) so sum all country's which is located in asian. 
df2['Asian']= df2.iloc[:,4]+df2.iloc[:,6]+df2.iloc[:,7]+df2.iloc[:,8]+df2.iloc[:,10]+df2.iloc[:,11]+df2.iloc[:,14]+df2.iloc[:,18]+df2.iloc[:,19]+df2.iloc[:,20]+df2.iloc[:,22]+df2.iloc[:,23]+df2.iloc[:,24]+df2.iloc[:,26]+df2.iloc[:,28]+df2.iloc[:,29]+df2.iloc[:,31]
+df2.iloc[:,32]+df2.iloc[:,40]

#Sum all westerners of our own accord
df2['Westerner']=df2.iloc[:,3]+df2.iloc[:,9]+df2.iloc[:,12]+df2.iloc[:,13]+df2.iloc[:,15]+df2.iloc[:,16]+df2.iloc[:,35]+df2.iloc[:,36]+df2.iloc[:,37]+df2.iloc[:,39]+df2.iloc[:,41]+df2.iloc[:,42]+df2.iloc[:,43]+df2.iloc[:,44]+df2.iloc[:,45]
+df2.iloc[:,47]+df2.iloc[:,48]+df2.iloc[:,50]+df2.iloc[:,56]


df2.head()
# Out:
#      2021   2021 .1  2021 .2  2021 .3  2021 .4  2021 .5  2021 .6  2021 .7  \
# 0   9106.0    992.0   2637.0    630.0    220.0    318.0   2111.0     71.0
# 1   9288.0   1294.0   2227.0    280.0    534.0    285.0   1424.0    265.0
# 2  14332.0    776.0    538.0   2554.0    314.0   1116.0    271.0    159.0
# 3   6682.0   1472.0   2151.0    225.0    137.0    243.0    945.0    205.0
# 4  12631.0   4049.0   3504.0    175.0    127.0    378.0   1585.0    856.0
#
#    2021 .8  2021 .9  ...  2021 .55  2021 .56  2021 .57  2021 .58  2021 .59  \
# 0     56.0     34.0  ...       5.0       4.0       7.0       0.0     239.0
# 1     95.0     96.0  ...      29.0      23.0      11.0       1.0     299.0
# 2    585.0    214.0  ...      52.0      48.0     103.0      77.0    1526.0
# 3    158.0     38.0  ...       2.0       6.0       8.0       2.0      88.0
# 4     89.0     45.0  ...       1.0       5.0       7.0       0.0     113.0
#
#      Total  Chinese  Japanese   Asian  Westerner
# ...

# %%
#make new dataframe only we need
df2_1=df2.copy()[['Total','Chinese','Japanese','Asian','Westerner']]
df2_1.head()
# Out:
#      Total  Chinese  Japanese   Asian  Westerner
# 0   9106.0   2637.0     318.0  3413.0     1102.0
# 1   9288.0   2227.0     285.0  3339.0     1529.0
# 2  14332.0    538.0    1116.0  3699.0     4429.0
# 3   6682.0   2151.0     243.0  2040.0      531.0
# 4  12631.0   3504.0     378.0  3898.0      521.0

# %%
#in our model we will use percentage of each type
df2_1['Percentage of Chinese']= df2_1['Chinese'] / df2_1['Total'] 
df2_1['Percentage of Japanese'] = df2_1['Japanese'] / df2_1['Total'] 
df2_1['Percentage of Asian']= df2_1['Asian'] / df2_1['Total'] 
df2_1['Percentage of Westerner']= df2_1['Westerner'] / df2_1['Total'] 

df2_1
# Out:
#       Total  Chinese  Japanese   Asian  Westerner  Percentage of Chinese  \
# 0    9106.0   2637.0     318.0  3413.0     1102.0               0.289589
# 1    9288.0   2227.0     285.0  3339.0     1529.0               0.239772
# 2   14332.0    538.0    1116.0  3699.0     4429.0               0.037538
# 3    6682.0   2151.0     243.0  2040.0      531.0               0.321910
# 4   12631.0   3504.0     378.0  3898.0      521.0               0.277413
# 5   14606.0   5703.0     544.0  5013.0      828.0               0.390456
# 6    4535.0    596.0     138.0  2318.0      173.0               0.131422
# 7    9614.0   3123.0     350.0  3833.0      851.0               0.324839
# 8    3381.0    603.0     119.0  1532.0      194.0               0.178350
# 9    2007.0    304.0     106.0   951.0      182.0               0.151470
# 10   3990.0    757.0     201.0  2006.0      401.0               0.189724
# 11   3866.0    703.0     360.0  1429.0      354.0               0.181842
# ...

# %%
#only left dataframe we need
Korea_foreign= df2_1[['Percentage of Chinese','Percentage of Japanese','Percentage of Asian','Percentage of Westerner']]

Korea_foreign
# Out:
#     Percentage of Chinese  Percentage of Japanese  Percentage of Asian  \
# 0                0.289589                0.034922             0.374808
# 1                0.239772                0.030685             0.359496
# 2                0.037538                0.077868             0.258094
# 3                0.321910                0.036366             0.305298
# 4                0.277413                0.029926             0.308606
# 5                0.390456                0.037245             0.343215
# 6                0.131422                0.030430             0.511136
# 7                0.324839                0.036405             0.398689
# 8                0.178350                0.035197             0.453120
# 9                0.151470                0.052815             0.473842
# 10               0.189724                0.050376             0.502757
# 11               0.181842                0.093120             0.369633
# ...

# %%
#put "Gu" information
Korea_foreign.insert(0,'Gu',['Jongno-gu',"Jung-gu","Yongsan-gu","Seongdong-gu","Gwangjin-gu","Dongdaemun-gu","Jungnang-gu","Seongbuk-gu","Gangbuk-gu","Dobong-gu","Nowon-gu","Eunpyeong-gu","Seodaemun-gu","Mapo-gu","Yangcheon-gu","Gangseo-gu","Guro-gu","Geumcheon-gu","Yeongdeungpo-gu","Dongjak-gu","Gwanak-gu","Seocho-gu","Gangnam-gu","Songpa-gu","Gangdong-gu"],True)
Korea_foreign.head()
# Out:
#              Gu  Percentage of Chinese  Percentage of Japanese  \
# 0     Jongno-gu               0.289589                0.034922
# 1       Jung-gu               0.239772                0.030685
# 2    Yongsan-gu               0.037538                0.077868
# 3  Seongdong-gu               0.321910                0.036366
# 4   Gwangjin-gu               0.277413                0.029926
#
#    Percentage of Asian  Percentage of Westerner
# 0             0.374808                 0.121019
# 1             0.359496                 0.164621
# 2             0.258094                 0.309029
# 3             0.305298                 0.079467
# 4             0.308606                 0.041248

# %%
Korea_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gu      25 non-null     object
#  1   Income  25 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 528.0+ bytes

# %%
#combine all information of income and population

#pd.concat([Korea_income,Korea_foreign],join='outer')
mergeDF=pd.merge(Korea_income,Korea_foreign,on='Gu',how='inner')
mergeDF
# Out:
#                  Gu    Income  Percentage of Chinese  Percentage of Japanese  \
# 0         Jongno-gu  8.092664               0.289589                0.034922
# 1           Jung-gu  7.359223               0.239772                0.030685
# 2        Yongsan-gu  8.214203               0.037538                0.077868
# 3      Seongdong-gu  8.231841               0.321910                0.036366
# 4       Gwangjin-gu  7.091238               0.277413                0.029926
# 5     Dongdaemun-gu  7.376686               0.390456                0.037245
# 6       Jungnang-gu  6.981943               0.131422                0.030430
# 7       Seongbuk-gu  7.101276               0.324839                0.036405
# 8        Gangbuk-gu  7.071233               0.178350                0.035197
# 9         Dobong-gu  6.829268               0.151470                0.052815
# 10         Nowon-gu  7.007524               0.189724                0.050376
# ...

# %%
df3 = pd.read_csv('data/Seoul_restaurant.csv', sep=',', encoding='cp949')
#investigate how data looks
df3.head()
# Out:
# C:\Users\oom67\AppData\Local\Temp\ipykernel_9184\1331501590.py:1: DtypeWarning: Columns (8,11,13,21,22,24,26,27,28,31,36,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv('data/Seoul_restaurant.csv', sep=',', encoding='cp949')
#     소재지우편번호                     지번주소                         도로명주소  도로명우편번호  \
# 0  110846.0   서울특별시 종로구 평창동 110-1번지        서울특별시 종로구 평창길 352 (평창동)   3004.0
# 1  110290.0      서울특별시 종로구 인사동 98번지   서울특별시 종로구 종로11길 10 12층 (인사동)   3164.0
# 2  110126.0  서울특별시 종로구 종로6가 129-1번지      서울특별시 종로구 종로41길 10 (종로6가)   3124.0
# 3  110043.0      서울특별시 종로구 통인동 27-2    서울특별시 종로구 필운대로6길 17-1 (통인동)   3036.0
# 4  110843.0     서울특별시 종로구 창신동 696-1         서울특별시 종로구 종로 289 (창신동)   3101.0
#
#         사업장명 업태구분명      좌표정보(X)      좌표정보(Y) 위생업태명  Unnamed: 9  ...  \
# 0     북악파크부페   뷔페식  197993.2057  456584.6271   뷔페식         NaN  ...
# 1   시민식당 2호점    한식  198681.5719  452050.2743    한식         NaN  ...
# ...

# %%
#get rid of useless columns 

#left only dataset we need
df3=df3.copy()[['도로명주소','업태구분명','좌표정보(X)','좌표정보(Y)']]

#Change the column names
df3.columns = ['Address','Type of Cuisine','TMCoordinate(X)','TMCoordinate(Y)']

#get rid of null dataset
df3 = df3.dropna(axis=0)
df3
# Out:
#                                         Address Type of Cuisine  \
# 0                       서울특별시 종로구 평창길 352 (평창동)             뷔페식
# 1                  서울특별시 종로구 종로11길 10 12층 (인사동)              한식
# 2                     서울특별시 종로구 종로41길 10 (종로6가)              분식
# 3                   서울특별시 종로구 필운대로6길 17-1 (통인동)              한식
# 4                        서울특별시 종로구 종로 289 (창신동)              기타
# ...                                         ...             ...
# 482342          서울특별시 용산구 한강대로 130-3 1층 (한강로2가)              기타
# 482343                서울특별시 양천구 곰달래로5길 85 (신월동)              기타
# 482344                  서울특별시 종로구 명륜길 31 (명륜3가)             중국식
# 482345         서울특별시 서대문구 연세로12길 28 (창천동(지상1층))              한식
# 482346  서울특별시 강서구 강서로 395 플레이스에이치 1층 107호 (마곡동)             중국식
#
#         TMCoordinate(X)  TMCoordinate(Y)
# 0           197993.2057      456584.6271
# 1           198681.5719      452050.2743
# 2           200533.4536      452156.9003
# ...

# %%
type = df3['Type of Cuisine'].str.contains("외국음식전문점|중국식|일식|경양식|패밀리레스토랑|제과점|패스트푸드")

# Filter the data that meets the condition and store it in a new variable.
df3 = df3[type]
df3
# Out:
#                                                Address Type of Cuisine  \
# 9                      서울특별시 종로구 북촌로5길 56-8 101호 (소격동)             경양식
# 10            서울특별시 영등포구 대림로 142 개풍빌딩 지하 1층 A05호 (대림동)              일식
# 13                      서울특별시 종로구 자하문로7길 36 지하1층 (통인동)             경양식
# 23                        서울특별시 종로구 종로51길 4 지하1층 (창신동)  외국음식전문점(인도태국등)
# 24      서울특별시 종로구 사직로8길 4 301동 B106호 (사직동 광화문 풍림스페이스본)              일식
# ...                                                ...             ...
# 482336                      서울특별시 강남구 도산대로49길 22 (신사동)             경양식
# 482338                      서울특별시 강남구 도산대로49길 22 (신사동)             경양식
# 482339             서울특별시 노원구 노원로 244 보스턴 산부인과 1층 (하계동)             중국식
# 482344                         서울특별시 종로구 명륜길 31 (명륜3가)             중국식
# 482346         서울특별시 강서구 강서로 395 플레이스에이치 1층 107호 (마곡동)             중국식
#
#         TMCoordinate(X)  TMCoordinate(Y)
# 9           198354.8041      453067.9971
# ...

# %%
#Change each district to english name with contains statement
df3.loc[df3['Address'].str.contains('종로구'),'Gu']='Jongno-gu'
df3.loc[df3['Address'].str.contains('중구'),'Gu']='Jung-gu'
df3.loc[df3['Address'].str.contains('용산구'),'Gu']='Yongsan-gu'
df3.loc[df3['Address'].str.contains('성동구'),'Gu']='Seongdong-gu'
df3.loc[df3['Address'].str.contains('광진구'),'Gu']='Gwangjin-gu'
df3.loc[df3['Address'].str.contains('동대문구'),'Gu']='Dongdaemun-gu'
df3.loc[df3['Address'].str.contains('중랑구'),'Gu']='Jungnang-gu'
df3.loc[df3['Address'].str.contains('성북구'),'Gu']='Seongbuk-gu'
df3.loc[df3['Address'].str.contains('강북구'),'Gu']='Gangbuk-gu'
df3.loc[df3['Address'].str.contains('도봉구'),'Gu']='Dobong-gu'
df3.loc[df3['Address'].str.contains('노원구'),'Gu']='Nowon-gu'
df3.loc[df3['Address'].str.contains('은평구'),'Gu']='Eunpyeong-gu'
df3.loc[df3['Address'].str.contains('서대문구'),'Gu']='Seodaemun-gu'
df3.loc[df3['Address'].str.contains('마포구'),'Gu']='Mapo-gu'
df3.loc[df3['Address'].str.contains('양천구'),'Gu']='Yangcheon-gu'
df3.loc[df3['Address'].str.contains('강서구'),'Gu']='Gangseo-gu'
df3.loc[df3['Address'].str.contains('구로구'),'Gu']='Guro-gu'
df3.loc[df3['Address'].str.contains('금천구'),'Gu']='Geumcheon-gu'
df3.loc[df3['Address'].str.contains('영등포구'),'Gu']='Yeongdeungpo-gu'
df3.loc[df3['Address'].str.contains('동작구'),'Gu']='Dongjak-gu'
df3.loc[df3['Address'].str.contains('관악구'),'Gu']='Gwanak-gu'
df3.loc[df3['Address'].str.contains('서초구'),'Gu']='Seocho-gu'
df3.loc[df3['Address'].str.contains('강남구'),'Gu']='Gangnam-gu'
df3.loc[df3['Address'].str.contains('송파구'),'Gu']='Songpa-gu'
df3.loc[df3['Address'].str.contains('강동구'),'Gu']='Gangdong-gu'
df3
# Out:
# C:\Users\oom67\AppData\Local\Temp\ipykernel_9184\3331560963.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.loc[df3['Address'].str.contains('종로구'),'Gu']='Jongno-gu'
#                                                Address Type of Cuisine  \
# 9                      서울특별시 종로구 북촌로5길 56-8 101호 (소격동)             경양식
# 10            서울특별시 영등포구 대림로 142 개풍빌딩 지하 1층 A05호 (대림동)              일식
# 13                      서울특별시 종로구 자하문로7길 36 지하1층 (통인동)             경양식
# 23                        서울특별시 종로구 종로51길 4 지하1층 (창신동)  외국음식전문점(인도태국등)
# 24      서울특별시 종로구 사직로8길 4 301동 B106호 (사직동 광화문 풍림스페이스본)              일식
# ...                                                ...             ...
# ...

# %%
#korean restaurant dataset is not fully divided so arbitrarily divide them
df3.loc[df3['Type of Cuisine'].str.contains('외국음식전문점'),'Type of Cuisine']='Asian'
df3.loc[df3['Type of Cuisine'].str.contains('중국식'),'Type of Cuisine']='Chinese'
df3.loc[df3['Type of Cuisine'].str.contains('일식'),'Type of Cuisine']='Japanese'
df3.loc[df3['Type of Cuisine'].str.contains('경양식'),'Type of Cuisine']='Western'
df3.loc[df3['Type of Cuisine'].str.contains('패밀리레스토랑'),'Type of Cuisine']='Western'
df3.loc[df3['Type of Cuisine'].str.contains('패스트푸드'),'Type of Cuisine']='Western'
df3.loc[df3['Type of Cuisine'].str.contains('제과점'),'Type of Cuisine']='Western'

# %%
#drop unneeded column
df3=df3.drop('Address', axis=1)
df3.head()
# Out:
#    Type of Cuisine  TMCoordinate(X)  TMCoordinate(Y)               Gu
# 9          Western      198354.8041      453067.9971        Jongno-gu
# 10        Japanese      191172.4825      443535.6795  Yeongdeungpo-gu
# 13         Western      197306.2268      452991.1322        Jongno-gu
# 23           Asian      201026.0290      452239.2282        Jongno-gu
# 24        Japanese      197181.3933      452458.8267        Jongno-gu

# %%
#get rid of strange data 
df3 = df3.drop(index=df3.loc[df3['Gu'] == '제주'].index)
df3 = df3.drop(index=df3.loc[df3['Gu'] == '성남'].index)
df3 = df3.drop(index=df3.loc[df3['Gu'] == '고양'].index)
df3 = df3.drop(index=df3.loc[df3['Gu'] == '부천'].index)
df3 = df3.drop(index=df3.loc[df3['Gu'] == '하남'].index)
df3 = df3.drop(index=df3.loc[df3['Gu'] == '知'].index)
df3
# Out:
#        Type of Cuisine  TMCoordinate(X)  TMCoordinate(Y)               Gu
# 9              Western      198354.8041      453067.9971        Jongno-gu
# 10            Japanese      191172.4825      443535.6795  Yeongdeungpo-gu
# 13             Western      197306.2268      452991.1322        Jongno-gu
# 23               Asian      201026.0290      452239.2282        Jongno-gu
# 24            Japanese      197181.3933      452458.8267        Jongno-gu
# ...                ...              ...              ...              ...
# 482336         Western      203232.6317      446906.3385       Gangnam-gu
# 482338         Western      203232.6317      446906.3385       Gangnam-gu
# 482339         Chinese      206490.5943      459688.0609         Nowon-gu
# 482344         Chinese      199506.1836      454029.3973        Jongno-gu
# 482346         Chinese      185679.0000      450992.0000       Gangseo-gu
#
# [41461 rows x 4 columns]

# %%
df3.reset_index(drop=True,inplace=True)
df3.head()
# Out:
#   Type of Cuisine  TMCoordinate(X)  TMCoordinate(Y)               Gu
# 0         Western      198354.8041      453067.9971        Jongno-gu
# 1        Japanese      191172.4825      443535.6795  Yeongdeungpo-gu
# 2         Western      197306.2268      452991.1322        Jongno-gu
# 3           Asian      201026.0290      452239.2282        Jongno-gu
# 4        Japanese      197181.3933      452458.8267        Jongno-gu

# %%
#we will use only 25 district so use mean of the coordinate
df4=df3.groupby('Gu').mean()
df4.head()
# Out:
#                TMCoordinate(X)  TMCoordinate(Y)
# Gu
# Dobong-gu        203346.183828    461826.916975
# Dongdaemun-gu    204716.654109    453263.592776
# Dongjak-gu       195670.845565    443932.468889
# Eunpyeong-gu     192807.096261    456262.664103
# Gangbuk-gu       202016.245964    458789.662165

# %%
#agiain put Gu column
df4.reset_index(drop=True,inplace=True)
df4.insert(0,'Gu',['Dobong-gu',"Dongdaemun-gu","Dongjak-gu","Eunpyeong-gu","Gangbuk-gu","Gangdong-gu","Gangnam-gu","Gangseo-gu","Geumcheon-gu","Guro-gu","Gwanak-gu","Gwangjin-gu","Jongno-gu","Jung-gu","Jungnang-gu","Mapo-gu","Nowon-gu","Seocho-gu","Seodaemun-gu","Seongbuk-gu","Seongdong-gu","Songpa-gu","Yangcheon-gu","Yeongdeungpo-gu","Yongsan-gu"],True)

df4.head()
# Out:
#               Gu  TMCoordinate(X)  TMCoordinate(Y)
# 0      Dobong-gu    203346.183828    461826.916975
# 1  Dongdaemun-gu    204716.654109    453263.592776
# 2     Dongjak-gu    195670.845565    443932.468889
# 3   Eunpyeong-gu    192807.096261    456262.664103
# 4     Gangbuk-gu    202016.245964    458789.662165

# %%
#just put num column to be changed
df3['num']=1
df3
# Out:
#       Type of Cuisine  TMCoordinate(X)  TMCoordinate(Y)               Gu  num
# 0             Western      198354.8041      453067.9971        Jongno-gu    1
# 1            Japanese      191172.4825      443535.6795  Yeongdeungpo-gu    1
# 2             Western      197306.2268      452991.1322        Jongno-gu    1
# 3               Asian      201026.0290      452239.2282        Jongno-gu    1
# 4            Japanese      197181.3933      452458.8267        Jongno-gu    1
# ...               ...              ...              ...              ...  ...
# 41456         Western      203232.6317      446906.3385       Gangnam-gu    1
# 41457         Western      203232.6317      446906.3385       Gangnam-gu    1
# 41458         Chinese      206490.5943      459688.0609         Nowon-gu    1
# 41459         Chinese      199506.1836      454029.3973        Jongno-gu    1
# 41460         Chinese      185679.0000      450992.0000       Gangseo-gu    1
#
# [41461 rows x 5 columns]

# %%
#count the number of restaurant in each 'Gu'
df3_count = df3.pivot_table("num", index="Gu",columns="Type of Cuisine", aggfunc="count")
#pdf2 = df3.pivot_table("가격", index="업체", aggfunc="sum")
df3_count
# Out:
# Type of Cuisine  Asian  Chinese  Japanese  Western
# Gu
# Dobong-gu           17      139       214      221
# Dongdaemun-gu       23      267       276      382
# Dongjak-gu          34      199       245      364
# Eunpyeong-gu        24      207       346      326
# Gangbuk-gu           4      164       200      206
# Gangdong-gu         51      240       321      362
# Gangnam-gu         285      660      1730     5576
# Gangseo-gu          55      353       566      917
# Geumcheon-gu        32      339       144      192
# Guro-gu             55      558       267      321
# Gwanak-gu           80      309       426      790
# Gwangjin-gu         65      377       493      540
# Jongno-gu          167      243       421     1481
# Jung-gu            182      366       570      899
# Jungnang-gu         19      167       224      205
# Mapo-gu            213      421       953     1239
# Nowon-gu            39      231       305      320
# ...

# %%
#make total column to calculate percentage
df3_count['Total'] = df3_count['Asian']+ df3_count['Chinese']+ df3_count['Japanese']+df3_count['Western']
df3_count
# Out:
# Type of Cuisine  Asian  Chinese  Japanese  Western  Total
# Gu
# Dobong-gu           17      139       214      221    591
# Dongdaemun-gu       23      267       276      382    948
# Dongjak-gu          34      199       245      364    842
# Eunpyeong-gu        24      207       346      326    903
# Gangbuk-gu           4      164       200      206    574
# Gangdong-gu         51      240       321      362    974
# Gangnam-gu         285      660      1730     5576   8251
# Gangseo-gu          55      353       566      917   1891
# Geumcheon-gu        32      339       144      192    707
# Guro-gu             55      558       267      321   1201
# Gwanak-gu           80      309       426      790   1605
# Gwangjin-gu         65      377       493      540   1475
# Jongno-gu          167      243       421     1481   2312
# Jung-gu            182      366       570      899   2017
# Jungnang-gu         19      167       224      205    615
# ...

# %%
#calculate percentage 
df3_count['percentage of Chinese R']= df3_count['Chinese'] / df3_count['Total'] 
df3_count['percentage of Japanese R'] = df3_count['Japanese'] / df3_count['Total'] 
df3_count['percentage of Asian R']= df3_count['Asian'] / df3_count['Total'] 
df3_count['percentage of Western R']= df3_count['Western'] / df3_count['Total'] 

df3_count
# Out:
# Type of Cuisine  Asian  Chinese  Japanese  Western  Total  \
# Gu
# Dobong-gu           17      139       214      221    591
# Dongdaemun-gu       23      267       276      382    948
# Dongjak-gu          34      199       245      364    842
# Eunpyeong-gu        24      207       346      326    903
# Gangbuk-gu           4      164       200      206    574
# Gangdong-gu         51      240       321      362    974
# Gangnam-gu         285      660      1730     5576   8251
# Gangseo-gu          55      353       566      917   1891
# Geumcheon-gu        32      339       144      192    707
# Guro-gu             55      558       267      321   1201
# Gwanak-gu           80      309       426      790   1605
# Gwangjin-gu         65      377       493      540   1475
# Jongno-gu          167      243       421     1481   2312
# Jung-gu            182      366       570      899   2017
# Jungnang-gu         19      167       224      205    615
# ...

# %%
#checking result
df3_fin= df3_count[['percentage of Chinese R','percentage of Japanese R','percentage of Asian R','percentage of Western R']]

df3_fin
# Out:
# Type of Cuisine  percentage of Chinese R  percentage of Japanese R  \
# Gu
# Dobong-gu                       0.235195                  0.362098
# Dongdaemun-gu                   0.281646                  0.291139
# Dongjak-gu                      0.236342                  0.290974
# Eunpyeong-gu                    0.229236                  0.383167
# Gangbuk-gu                      0.285714                  0.348432
# Gangdong-gu                     0.246407                  0.329569
# Gangnam-gu                      0.079990                  0.209672
# Gangseo-gu                      0.186674                  0.299313
# Geumcheon-gu                    0.479491                  0.203678
# Guro-gu                         0.464613                  0.222315
# Gwanak-gu                       0.192523                  0.265421
# Gwangjin-gu                     0.255593                  0.334237
# Jongno-gu                       0.105104                  0.182093
# ...

# %%
#make index to match dataset of income and population
df3_fin.reset_index(drop=True,inplace=True)
df3_fin.insert(0,'Gu',['Dobong-gu',"Dongdaemun-gu","Dongjak-gu","Eunpyeong-gu","Gangbuk-gu","Gangdong-gu","Gangnam-gu","Gangseo-gu","Geumcheon-gu","Guro-gu","Gwanak-gu","Gwangjin-gu","Jongno-gu","Jung-gu","Jungnang-gu","Mapo-gu","Nowon-gu","Seocho-gu","Seodaemun-gu","Seongbuk-gu","Seongdong-gu","Songpa-gu","Yangcheon-gu","Yeongdeungpo-gu","Yongsan-gu"],True)

df3_fin.head()
# Out:
# Type of Cuisine             Gu  percentage of Chinese R  \
# 0                    Dobong-gu                 0.235195
# 1                Dongdaemun-gu                 0.281646
# 2                   Dongjak-gu                 0.236342
# 3                 Eunpyeong-gu                 0.229236
# 4                   Gangbuk-gu                 0.285714
#
# Type of Cuisine  percentage of Japanese R  percentage of Asian R  \
# 0                                0.362098               0.028765
# 1                                0.291139               0.024262
# 2                                0.290974               0.040380
# 3                                0.383167               0.026578
# 4                                0.348432               0.006969
#
# Type of Cuisine  percentage of Western R
# 0                               0.373942
# 1                               0.402954
# 2                               0.432304
# 3                               0.361019
# ...

# %%
#merge all restaurant datasets
mergeR=pd.merge(df4,df3_fin,on='Gu',how='inner')

mergeR
# Out:
#                  Gu  TMCoordinate(X)  TMCoordinate(Y)  \
# 0         Dobong-gu    203346.183828    461826.916975
# 1     Dongdaemun-gu    204716.654109    453263.592776
# 2        Dongjak-gu    195670.845565    443932.468889
# 3      Eunpyeong-gu    192807.096261    456262.664103
# 4        Gangbuk-gu    202016.245964    458789.662165
# 5       Gangdong-gu    212146.064845    448833.437964
# 6        Gangnam-gu    203543.578802    445389.564025
# 7        Gangseo-gu    185708.296293    450214.632871
# 8      Geumcheon-gu    190575.558799    440857.219211
# 9           Guro-gu    189325.108584    443482.431581
# 10        Gwanak-gu    194624.060025    441999.884598
# 11      Gwangjin-gu    206882.348099    449119.563757
# 12        Jongno-gu    198737.599776    452764.026088
# 13          Jung-gu    199141.891642    451215.742075
# 14      Jungnang-gu    207634.337491    454853.016758
# 15          Mapo-gu    193036.272963    450368.869007
# ...

# %%
#finally merge all korean datasets
Korea_Df=pd.merge(mergeDF,mergeR,on='Gu',how='inner')

Korea_Df
# Out:
#                  Gu    Income  Percentage of Chinese  Percentage of Japanese  \
# 0         Jongno-gu  8.092664               0.289589                0.034922
# 1           Jung-gu  7.359223               0.239772                0.030685
# 2        Yongsan-gu  8.214203               0.037538                0.077868
# 3      Seongdong-gu  8.231841               0.321910                0.036366
# 4       Gwangjin-gu  7.091238               0.277413                0.029926
# 5     Dongdaemun-gu  7.376686               0.390456                0.037245
# 6       Jungnang-gu  6.981943               0.131422                0.030430
# 7       Seongbuk-gu  7.101276               0.324839                0.036405
# 8        Gangbuk-gu  7.071233               0.178350                0.035197
# 9         Dobong-gu  6.829268               0.151470                0.052815
# 10         Nowon-gu  7.007524               0.189724                0.050376
# ...
